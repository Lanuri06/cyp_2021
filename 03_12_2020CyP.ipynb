# %% [markdown]
# <a href="https://colab.research.google.com/github/Lanuri06/cyp_2021/blob/main/03_12_2020CyP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ejemplo 1
for i in[1,2,3,4,5]:
  print(f"el elemento:{i}")
# Out:
# el elemento:1
# el elemento:2
# el elemento:3
# el elemento:4
# el elemento:5

# %%
coleccion=[1,2,3,4,5]
for i in coleccion:
  print(f" El elemento: {i} ")
# Out:
#  El elemento: 1
#  El elemento: 2
#  El elemento: 3
#  El elemento: 4
#  El elemento: 5

# %%
#Ejemplo 2

coleccion={" Mario":20, "Mariana":19, "Yessica":14, "Luis": 18}
for i in coleccion:
  print(f" Elemento: {i}")
# Out:
#  Elemento:  Mario
#  Elemento: Mariana
#  Elemento: Yessica
#  Elemento: Luis

# %%
coleccion={" Mario":20, "Mariana":19, "Yessica":14, "Luis": 18}
for i in coleccion:
  print(f" {coleccion [i]}")
# Out:
#  20
#  19
#  14
#  18

# %%
coleccion={" Mario":20, "Mariana":19, "Yessica":14, "Luis": 18}
for i in coleccion:
  print(f"{i}->{coleccion[i]}")
# Out:
#  Mario->20
# Mariana->19
# Yessica->14
# Luis->18

# %%
coleccion={" Mario":20, "Mariana":19, "Yessica":14, "Luis": 18}

for clave, valor in coleccion.items():
  print(f"{clave} ->{valor}")
# Out:
#  Mario ->20
# Mariana ->19
# Yessica ->14
# Luis ->18

# %%
#Ejemplo 3

email=False
for i in"ariel@unam.mx":
  if(i=="@"):
    email=True
if email== True:
  print(" El email es correcto")

else:
  print(" El email no es correcto")
# Out:
#  El email es correcto

# %%
email=False
miEmail= input( " Introduce tu correo electrónico: ")

for i in miEmail:
  if(i=="@"):
    email=True

if email:
  print(" El email es correcto")

else:
  print(" El email no es correcto")
# Out:
#  Introduce tu correo electrónico: anita@unam.com
#  El email es correcto

# %%
#For-Range

for i in range (5):
  print(" Hola!")
# Out:
#  Hola!
#  Hola!
#  Hola!
#  Hola!
#  Hola!

# %%
for i in range (5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (20):
  print(f" Valor de la variable {i} ")
# Out:
#  Valor de la variable 0
#  Valor de la variable 1
#  Valor de la variable 2
#  Valor de la variable 3
#  Valor de la variable 4
#  Valor de la variable 5
#  Valor de la variable 6
#  Valor de la variable 7
#  Valor de la variable 8
#  Valor de la variable 9
#  Valor de la variable 10
#  Valor de la variable 11
#  Valor de la variable 12
#  Valor de la variable 13
#  Valor de la variable 14
#  Valor de la variable 15
#  Valor de la variable 16
#  Valor de la variable 17
#  Valor de la variable 18
#  Valor de la variable 19

# %%
#While Ejemplos

#Ejemplo 1

i=1
while i <=10:
  print("Ejecucion"+ str(i))
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# Ejecucion1
# ...

# %%
i=1
while i <=10:
    print("Ejecucion "+str(i))

    i=i+1 #Contador , es decir , incrementa en 1 la variable
# Out:
# Ejecucion 1
# Ejecucion 2
# Ejecucion 3
# Ejecucion 4
# Ejecucion 5
# Ejecucion 6
# Ejecucion 7
# Ejecucion 8
# Ejecucion 9
# Ejecucion 10

# %%
edad=int(input("Introduce tu edad: "))
while edad < 0:
  print(" Has introducido una edad negativa, inténtalo de nuevo")
  edad=int(input(" Introduce tu edad: "))
print(" Gracias por participar.Puede pasar")
print(" Edad del aspirante: " + str (edad))
# Out:
# Introduce tu edad: 19
#  Gracias por participar.Puede pasar
#  Edad del aspirante: 19

# %%
edad=int(input("Introduce tu edad:"))
while edad < 10 or edad >= 100:
  print("Has introducido una edad negativa, Intentalo de nuevo")
  edad=int(input("Introduce tu edad: "))
print("Gracias por participar.Puede pasar")  
print("Edad del aspirante: "+str (edad))
# Out:
# Introduce tu edad:9
# Has introducido una edad negativa, Intentalo de nuevo
# Introduce tu edad: 99
# Gracias por participar.Puede pasar
# Edad del aspirante: 99
